# %%
import requests
import pandas as pd
resp = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')
type(resp)
# Out:
# requests.models.Response

# %%
data = resp.json()

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39401',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39401/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39401/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/39401/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/39401',
#   'id': 793607430,
#   'node_id': 'MDU6SXNzdWU3OTM2MDc0MzA=',
#   'number': 39401,
#   'title': 'ValueError when concatenating a length-one, reversed object',
#   'user': {'login': 'ahawryluk',
#    'id': 50434302,
#    'node_id': 'MDQ6VXNlcjUwNDM0MzAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50434302?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ahawryluk',
#    'html_url': 'https://github.com/ahawryluk',
# ...

# %%
data[5]['labels']
# Out:
# [{'id': 1728592794,
#   'node_id': 'MDU6TGFiZWwxNzI4NTkyNzk0',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Styler',
#   'name': 'Styler',
#   'color': '006b75',
#   'default': False,
#   'description': 'conditional formatting using DataFrame.style'}]

# %%
len(data)
# Out:
# 30

# %%
for i in range(len(data)):
    print(data[i]['labels'])
# Out:
# []
# [{'id': 1954720290, 'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage', 'name': 'Needs Triage', 'color': '0052cc', 'default': False, 'description': 'Issue that has not been reviewed by a pandas team member'}, {'id': 34444536, 'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question', 'name': 'Usage Question', 'color': '0052cc', 'default': False, 'description': None}]
# [{'id': 1280988427, 'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing', 'name': 'Typing', 'color': 'ea91a4', 'default': False, 'description': 'mypy type annotations'}]
# ...

# %%
issues = pd.DataFrame(data,columns=['number','title','labels','state'])

# %%
issues
# Out:
#     number                                              title  \
# 0    39401  ValueError when concatenating a length-one, re...
# 1    39400  QST: Styler puts all CSS ids on a single attri...
# 2    39399                  TYP upgrade and pin mypy to 0.800
# 3    39398  BUG: `DateTimeIndex + DateTimeIndex.freq` givi...
# 4    39397  QST: When using df.loc[ ] in a for loop I get ...
# 5    39396  BUG: re-render CSS with `styler.apply` and `ap...
# 6    39395  BUG: `Styler.apply` and `applymap` duplicate C...
# 7    39394  ENH: Fix support for matplotlib's constrained_...
# 8    39393  ENH: `Styler.apply` accept ndarray return with...
# 9    39392             CI: split benchmarks from other checks
# 10   39390             CI: save site+docs builds as artifacts
# 11   39389  BUG: DataFrame to_dict method raise Out of bou...
# 12   39386                             TST: remove test_error
# 13   39383  REF: in pandas.io.common integerate BytesIOWra...
# ...

# %%
issues = pd.DataFrame(data,columns=['url','comments_url', 'comments_url','html_url','user','labels',
                                    data['user']['login']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-6c458a088cde> in <module>
#       1 issues = pd.DataFrame(data,columns=['url','comments_url', 'comments_url','html_url','user','labels',
# ----> 2                                     data['user']['login']])
#
# TypeError: list indices must be integers or slices, not str

# %%
data[1]['user']['id']

# %%
print(data[1]['user']['id'],'  ',data[1]['user']['node_id'],' ',data[1]['user']['url'],'  ',data[1]['user']['html_url'])

# %%
data[5]['labels']
# Out:
# [{'id': 1728592794,
#   'node_id': 'MDU6TGFiZWwxNzI4NTkyNzk0',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Styler',
#   'name': 'Styler',
#   'color': '006b75',
#   'default': False,
#   'description': 'conditional formatting using DataFrame.style'}]

# %%
for i in range(len(data)):
    for j in range(len(data[i]['labels'])):
        print(data[i]['number'],'  ',data[i]['title'],'  ',data[i]['labels'][j]['id'], '  ',data[i]['labels'][j]['node_id'],'  ',data[i]['labels'][j]['url'],'  ',
              data[i]['labels'][j]['name'],'  ',data[i]['labels'][j]['color'],'  ',data[i]['labels'][j]['default'],
             '  ',data[i]['labels'][j]['description'],'\n')
# Out:
# 39400    QST: Styler puts all CSS ids on a single attribute which is not rendered    1954720290    MDU6TGFiZWwxOTU0NzIwMjkw    https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage    Needs Triage    0052cc    False    Issue that has not been reviewed by a pandas team member
#
# 39400    QST: Styler puts all CSS ids on a single attribute which is not rendered    34444536    MDU6TGFiZWwzNDQ0NDUzNg==    https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question    Usage Question    0052cc    False    None
#
# 39399    TYP upgrade and pin mypy to 0.800    1280988427    MDU6TGFiZWwxMjgwOTg4NDI3    https://api.github.com/repos/pandas-dev/pandas/labels/Typing    Typing    ea91a4    False    mypy type annotations
#
# 39398    BUG: `DateTimeIndex + DateTimeIndex.freq` giving incorrect result if timezone is set.    76811    MDU6TGFiZWw3NjgxMQ==    https://api.github.com/repos/pandas-dev/pandas/labels/Bug    Bug    e10c02    False    None
#
# ...

# %%
for i in range(len(data)):
    for j in range(len(data[i]['labels'])):
        print(data[i]['labels'][j]['id'])
# Out:
# 1954720290
# 34444536
# 1280988427
# 76811
# 1954720290
# 1954720290
# 34444536
# 1728592794
# 76811
# 1728592794
# 732775912
# 48070600
# 48070600
# 134699
# 1508144531
# 76811
# 31404521
# 219960758
# 211840
# 849023693
# 127685
# 47229171
# 49094459
# 1954720290
# 127681
# 2822098
# 1625435109
# 697792067
# 134699
# 1357732944
# 42670965
# 2822098
# 76812
# 1954720290
# 2187005593
# 134699
# 219960758
# 1508144531
# 134699
# 717120670
# 47229171
# 127681
# 134699
# 134699
# 76812
# 1728592794

# %%
for i in range(len(data)):
    for j in range(len(data[i]['labels'])):
        if data[i]['labels'][j]['id'] == 76811 :
            print(data[i]['labels'],'\n')
# Out:
# [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug', 'name': 'Bug', 'color': 'e10c02', 'default': False, 'description': None}, {'id': 1954720290, 'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage', 'name': 'Needs Triage', 'color': '0052cc', 'default': False, 'description': 'Issue that has not been reviewed by a pandas team member'}]
#
# [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug', 'name': 'Bug', 'color': 'e10c02', 'default': False, 'description': None}, {'id': 1728592794, 'node_id': 'MDU6TGFiZWwxNzI4NTkyNzk0', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Styler', 'name': 'Styler', 'color': '006b75', 'default': False, 'description': 'conditional formatting using DataFrame.style'}]
#
# ...

# %%
for i in range(len(data)):
    for j in range(len(data[i]['labels'])):
        if i == 5:
            print(data[i]['number'],'  ',data[i]['title'],'  ',data[i]['labels'][j]['id'], '  ',data[i]['labels'][j]['node_id'],'  ',data[i]['labels'][j]['url'],'  ',
                  data[i]['labels'][j]['name'],'  ',data[i]['labels'][j]['color'],'  ',data[i]['labels'][j]['default'],
                 '  ',data[i]['labels'][j]['description'],'\n')
# Out:
# 39396    BUG: re-render CSS with `styler.apply` and `applymap` non-cleared ` _todo`    1728592794    MDU6TGFiZWwxNzI4NTkyNzk0    https://api.github.com/repos/pandas-dev/pandas/labels/Styler    Styler    006b75    False    conditional formatting using DataFrame.style

# %%
id': 134699,
    'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
    'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
    'name': 'Docs',
    'color': '3465A4',
    'default': False,
    'description': None},
# Out:
#   File "<ipython-input-16-36bee60af133>", line 1
#     id': 134699,
#                 ^
# SyntaxError: EOL while scanning string literal

# %%
x = []
for i in range(len(data)):
    for j in range(len(data[i]['labels'])):
        s = (data[i]['number'],data[i]['title'],data[i]['labels'][j]['id'],data[i]['labels'][j]['node_id'],data[i]['labels'][j]['url'],
              data[i]['labels'][j]['name'],data[i]['labels'][j]['color'],data[i]['labels'][j]['default'],data[i]['labels'][j]['description'])
        x.append(s)

df = pd.DataFrame(x,columns=['number','title', 'id','node_id', 'url' ,'name','color','default','description']).head()
#df = pd.DataFrame(x,index=None)

# %%
df
# Out:
#    number                                              title          id  \
# 0   39400  QST: Styler puts all CSS ids on a single attri...  1954720290
# 1   39400  QST: Styler puts all CSS ids on a single attri...    34444536
# 2   39399                  TYP upgrade and pin mypy to 0.800  1280988427
# 3   39398  BUG: `DateTimeIndex + DateTimeIndex.freq` givi...       76811
# 4   39398  BUG: `DateTimeIndex + DateTimeIndex.freq` givi...  1954720290
#
#                     node_id  \
# 0  MDU6TGFiZWwxOTU0NzIwMjkw
# 1  MDU6TGFiZWwzNDQ0NDUzNg==
# 2  MDU6TGFiZWwxMjgwOTg4NDI3
# 3      MDU6TGFiZWw3NjgxMQ==
# 4  MDU6TGFiZWwxOTU0NzIwMjkw
#
#                                                  url            name   color  \
# 0  https://api.github.com/repos/pandas-dev/pandas...    Needs Triage  0052cc
# 1  https://api.github.com/repos/pandas-dev/pandas...  Usage Question  0052cc
# 2  https://api.github.com/repos/pandas-dev/pandas...          Typing  ea91a4
# ...

# %% [markdown]
# call = pd.read_csv(raw.githubusercontent.com/PramodShenoy/911-Calls/master/911.cav'
# 1. desc for categorical, numerical
# 2. column lat typecast into INT and groupby and count
# 3. How many people ar efrom same zip location
# 4. Check timestamp datatype and extract dayin new column
# 5. filterout all the zip code coulumn wth address column starts with a
# 6. tye to map timestamp with day like Mon, Tue, Wed ....
# 7. title column extract servie detail (exp: emergency, fire etc)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/PramodShenoy/911-Calls/master/911.csv')

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %%
df.columns
# Out:
# Index(['lat', 'lng', 'desc', 'zip', 'title', 'timeStamp', 'twp', 'addr', 'e'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 9 columns):
# lat          99492 non-null float64
# lng          99492 non-null float64
# desc         99492 non-null object
# zip          86637 non-null float64
# title        99492 non-null object
# timeStamp    99492 non-null object
# twp          99449 non-null object
# addr         98973 non-null object
# e            99492 non-null int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.8+ MB

# %%
df.describe()
# Out:
#                 lat           lng           zip        e
# count  99492.000000  99492.000000  86637.000000  99492.0
# mean      40.159526    -75.317464  19237.658298      1.0
# std        0.094446      0.174826    345.344914      0.0
# min       30.333596    -95.595595  17752.000000      1.0
# 25%       40.100423    -75.392104  19038.000000      1.0
# 50%       40.145223    -75.304667  19401.000000      1.0
# 75%       40.229008    -75.212513  19446.000000      1.0
# max       41.167156    -74.995041  77316.000000      1.0

# %%
df.dtypes[df.dtypes=='object'].describe()
# Out:
# count          5
# unique         1
# top       object
# freq           5
# dtype: object

# %%
pd.DataFrame(df.dtypes[df.dtypes=='object']).T.columns
# Out:
# Index(['desc', 'title', 'timeStamp', 'twp', 'addr'], dtype='object')

# %%
#column lat typecast into INT and groupby and count
df['lat'] = df['lat'].astype('int64')

# %%
df.groupby('lat').count()
# Out:
#        lng   desc    zip  title  timeStamp    twp   addr      e
# lat
# 30       1      1      1      1          1      1      1      1
# 32       1      1      1      1          1      1      1      1
# 39    1477   1477   1415   1477       1477   1477   1475   1477
# 40   98012  98012  85219  98012      98012  97970  97495  98012
# 41       1      1      1      1          1      0      1      1

# %%
#How many people ar efrom same zip location
#Check timestamp datatype and extract dayin new column
#filterout all the zip code coulumn wth address column starts with a
#tye to map timestamp with day like Mon, Tue, Wed ....
#title column extract servie detail (exp: emergency, fire etc)

# %%
#How many people ar efrom same zip location
(df.groupby('zip').count()).loc(axis=1)['addr']
# Out:
# zip
# 17752.0       1
# 18036.0       2
# 18041.0     414
# 18054.0     325
# 18056.0       6
# 18070.0      54
# 18073.0     736
# 18074.0     435
# 18076.0     306
# 18092.0      14
# 18103.0       0
# 18914.0      65
# 18915.0     118
# 18927.0       2
# 18932.0      11
# 18936.0     254
# 18951.0      10
# 18960.0      34
# 18964.0    1287
# 18966.0      44
# 18969.0     672
# 18974.0     215
# 18976.0      45
# 19001.0    1514
# 19002.0    3050
# 19003.0    1094
# 19004.0    1280
# 19006.0    2256
# 19009.0      49
# 19010.0    1316
#            ...
# 19423.0       4
# 19426.0    2450
# 19428.0    2295
# 19435.0      35
# 19438.0    1988
# 19440.0    1190
# 19444.0    1008
# 19446.0    4745
# 19453.0     101
# 19454.0    2780
# 19457.0       1
# 19460.0     427
# 19462.0    2078
# 19464.0    6642
# 19465.0     458
# 19468.0    2976
# 19472.0       6
# 19473.0    1010
# 19475.0      73
# 19477.0      10
# 19490.0       1
# 19492.0      40
# 19503.0       4
# 19504.0     101
# ...

# %%
#Check timestamp datatype and extract dayin new column
df.head()
# Out:
#    lat        lng                                               desc      zip  \
# 0   40 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1   40 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2   40 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3   40 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4   40 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
#
#                      title            timeStamp                twp  \
# 0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# ...

# %%
df['day'] = pd.to_datetime(df['timeStamp'])

# %%
df
# Out:
#        lat        lng                                               desc  \
# 0       40 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1       40 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2       40 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3       40 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4       40 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
# 5       40 -75.283245  CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...
# 6       40 -75.127795  LAUREL AVE & OAKDALE AVE;  HORSHAM; Station 35...
# 7       40 -75.405182  COLLEGEVILLE RD & LYWISKI RD;  SKIPPACK; Stati...
# 8       40 -75.399590  MAIN ST & OLD SUMNEYTOWN PIKE;  LOWER SALFORD;...
# 9       40 -75.291458  BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...
# 10      40 -75.251891  RT202 PKWY & KNAPP RD; MONTGOMERY; 2015-12-10 ...
# 11      40 -75.308386  BROOK RD & COLWELL LN; PLYMOUTH; 2015-12-10 @ ...
# ...

# %%
df['day'] = df['day'].dt.day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-210-e7e7398634dc> in <module>
# ----> 1 df['day'] = df['day'].dt.day_name()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
# ...

# %%
df
# Out:
#        lat        lng                                               desc  \
# 0       40 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1       40 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2       40 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3       40 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4       40 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
# 5       40 -75.283245  CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...
# 6       40 -75.127795  LAUREL AVE & OAKDALE AVE;  HORSHAM; Station 35...
# 7       40 -75.405182  COLLEGEVILLE RD & LYWISKI RD;  SKIPPACK; Stati...
# 8       40 -75.399590  MAIN ST & OLD SUMNEYTOWN PIKE;  LOWER SALFORD;...
# 9       40 -75.291458  BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...
# 10      40 -75.251891  RT202 PKWY & KNAPP RD; MONTGOMERY; 2015-12-10 ...
# 11      40 -75.308386  BROOK RD & COLWELL LN; PLYMOUTH; 2015-12-10 @ ...
# ...

# %%
#filterout all the zip code coulumn wth address column starts with a
df['addr'] = df['addr']

# %%
df
# Out:
#        lat        lng                                               desc  \
# 0       40 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1       40 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2       40 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3       40 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4       40 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
# 5       40 -75.283245  CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...
# 6       40 -75.127795  LAUREL AVE & OAKDALE AVE;  HORSHAM; Station 35...
# 7       40 -75.405182  COLLEGEVILLE RD & LYWISKI RD;  SKIPPACK; Stati...
# 8       40 -75.399590  MAIN ST & OLD SUMNEYTOWN PIKE;  LOWER SALFORD;...
# 9       40 -75.291458  BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...
# 10      40 -75.251891  RT202 PKWY & KNAPP RD; MONTGOMERY; 2015-12-10 ...
# 11      40 -75.308386  BROOK RD & COLWELL LN; PLYMOUTH; 2015-12-10 @ ...
# ...
